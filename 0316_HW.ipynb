# %% [markdown]
# <a href="https://colab.research.google.com/github/s10950026/bigdata/blob/main/0316_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
system("ls",TRUE)
# Out:
# [1] "sample_data"

# %%
library(readr)

# %%
dataset <- read.csv("1101.csv")

# %%
dataset
# Out:
#    區域別 性別 總計總計 總計本國籍合計 總計本國籍已設籍 總計本國籍未設籍
# 1  臺南市 男   266      264            264              0
# 2  臺南市 女   266      234            234              0
# 3  新營區 男     7        7              7              0
# 4  新營區 女     7        7              7              0
# 5  鹽水區 男     2        2              2              0
# 6  鹽水區 女     2        2              2              0
# 7  白河區 男     2        2              2              0
# 8  白河區 女     2        2              2              0
# 9  柳營區 男     5        5              5              0
# 10 柳營區 女     5        4              4              0
# 11 後壁區 男     4        4              4              0
# 12 後壁區 女     4        3              3              0
# 13 東山區 男     2        2              2              0
# 14 東山區 女     2        1              1              0
# 15 麻豆區 男     9        8              8              0
# 16 麻豆區 女     9        7              7              0
# 17 下營區 男     4        4              4              0
# ...

# %%
head(dataset$區域別,n=10)
# Out:
#  [1] "臺南市" "臺南市" "新營區" "新營區" "鹽水區" "鹽水區" "白河區" "白河區"
#  [9] "柳營區" "柳營區"

# %%
tail(dataset$區域別,n=10)
# Out:
#  [1] "南區"   "南區"   "北區"   "北區"   "安南區" "安南區" "安平區" "安平區"
#  [9] "中西區" "中西區"

# %%
dataset[grepl("中西區",dataset$區域別),]
# Out:
#    區域別 性別 總計總計 總計本國籍合計 總計本國籍已設籍 總計本國籍未設籍
# 75 中西區 男   10       10             10               0
# 76 中西區 女   10        9              9               0
#    總計大陸地區合計 總計大陸地區已設籍 總計大陸地區未設籍 總計港澳地區合計 ⋯
# 75 0                0                  0                  0                ⋯
# 76 1                1                  0                  0                ⋯
#    相同性別外國籍其他國籍澳大利亞 相同性別外國籍其他國籍紐西蘭
# 75 0                              0
# 76 0                              0
#    相同性別外國籍其他國籍英國 相同性別外國籍其他國籍法國
# 75 0                          0
# 76 0                          0
#    相同性別外國籍其他國籍德國 相同性別外國籍其他國籍史瓦帝尼
# 75 0                          0
# 76 0                          0
#    相同性別外國籍其他國籍南非 相同性別外國籍其他國籍賴索托
# 75 0                          0
# 76 0                          0
#    相同性別外國籍其他國籍模里西斯 相同性別外國籍其他國籍其他
# 75 0                              0
# 76 0                              0

# %%
dataset[grepl("安平區",dataset$區域別),]
# Out:
#    區域別 性別 總計總計 總計本國籍合計 總計本國籍已設籍 總計本國籍未設籍
# 73 安平區 男   12       12             12               0
# 74 安平區 女   12       12             12               0
#    總計大陸地區合計 總計大陸地區已設籍 總計大陸地區未設籍 總計港澳地區合計 ⋯
# 73 0                0                  0                  0                ⋯
# 74 0                0                  0                  0                ⋯
#    相同性別外國籍其他國籍澳大利亞 相同性別外國籍其他國籍紐西蘭
# 73 0                              0
# 74 0                              0
#    相同性別外國籍其他國籍英國 相同性別外國籍其他國籍法國
# 73 0                          0
# 74 0                          0
#    相同性別外國籍其他國籍德國 相同性別外國籍其他國籍史瓦帝尼
# 73 0                          0
# 74 0                          0
#    相同性別外國籍其他國籍南非 相同性別外國籍其他國籍賴索托
# 73 0                          0
# 74 0                          0
#    相同性別外國籍其他國籍模里西斯 相同性別外國籍其他國籍其他
# 73 0                              0
# 74 0                              0
